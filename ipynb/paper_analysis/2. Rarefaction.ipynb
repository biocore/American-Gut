# %%
# %matplotlib inline

# %% [markdown]
# <a id="top"></a>
#
# # Rarefaction
# I'd like to look at the effect of rarefaction on the number of OTUs we see, and on the power.
#
# ####Notebook Requirements
# <ul><li>Python 2.7
# </li><li>Numpy $\geq$ 1.7
# </li><li>Biom format 2.0.1
# </li><li>Pandas 0.14.1
# </li><li>StatsModel 0.5.0
# </li><li>Scikit bio 0.1.4
# </li><li>Qiime 1.8.0-dev
# </li><li>Custom code libraries, <a href="">pandas_fun.py</a> and <a href="">power.py</a>.
# </li></ul>
#
# ####Table of contents
# <ul><li><a href="#parameters">Sets analysis parameters</a>
# </li><li><a href="#ifilepath">Imports necessary files</a>
# </li><li><a href="#rare">Multiple Rarefaction</a>
# </li></ul>
#
#
# We start by importing necessary functions, and determining if files should be overwritten.

# %%
# File handling
from os import remove, rename, mkdir
from os.path import abspath, isfile, exists, join as pjoin
from shutil import move
# Random sampling
from random import sample
# Numerical operations
from numpy import nan, isnan, mean, std, array, arange, power, ones, hstack, zeros, median
# Statitics
from scipy.stats import kruskal
from statsmodels.stats.power import FTestAnovaPower
# Plotting
from matplotlib import rcParams
import matplotlib.pylab as plt
# Pandas data frame
from pandas import read_csv, Series, DataFrame
# Distance matrix handling
from skbio import DistanceMatrix
# Biom handling
from biom import load_table
# Specialzied function
from jwd_code.pandas_fun import (check_dir, 
                                 pad_index)

from power.power_analysis import bootstrap_power_curve
# Out:
# /Users/jwdebelius/.virtualenvs/qiime_dev/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# We will also set up some plotting parameters so the generated figures use Helvetica or Arial as their default font.

# %%
# Sets up plotting parameters so that the default setting is use to Helvetica
# in plots
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica', 'Arial']
rcParams['text.usetex'] = True

# %% [markdown]
# <a href=#top>Return to the top</a>
#
# <a id="parameters"></a>
# ###### Sets analysis parameters
#
# We can also set some necessary parameters for handling files and this analysis.
#
# ###### Pandas filehandling parameters
# <ul><li>The <strong><code>txt_delim</code></strong> specifies the way columns are seperated in the files. Qiime standards typically use text (<code>.txt</code>) files, which are seperated by a tab-character (<code><font color="FireBrick">'\t'</font></code>).
# </li><li><strong><code>map_index</code></strong> specifies the name of the file containing the sample names. In Qiime, this is named #SampleID.
# </li><li>Possible empty values, <strong><code>map_nas</code></strong> provides a list of values which specify data has not been supplied. American Gut participants are free to skip any survey question they do not wish to answer. As a result, the mapping file can contain  empty or missing-data fields.
# </li><li><strong><code>write_na</code></strong> gives a value used when the files are written. Using an empty space, <code><font color="FireBrick">''</font></code>, scripts like <code>group_signifigance.py</code> will ignore the group.
# </li></ul>
#
#
# ##### Rarefaction Parameters
# <ul><li><strong><code>rare_depths</code></strong> gives the rarefaction depths (number of sequences per sample) to draw.
# </li><li><strong><code>num_samps</code></strong>: the number of samples to draw from each table.
# </li><li><strong><code>num_rarefactions</code></strong> specifies the number of rarefactions to perform for each point on the landscape.
# </li></ul>

# %%
overwrite = False

# Sets parameters for reading tables into pandas
txt_delim = '\t'
map_index = '#SampleID'
map_nas = ['NA', 'no_data', 'unknown']
write_na = ''

# Sets the rarefaction and sample number parameters
rare_depths = hstack((array([100, 500, 1000]), arange(2000, 52000, 2000)))
samps_drawn = hstack((arange(2, 9, 2), arange(10, 100, 20), arange(100, 500, 50), arange(500, 1000, 100),
                      arange(1000, 2500, 250)))
num_iterations = 5
num_rarefactions = rare_depths.shape[0]
num_samples = samps_drawn.shape[0]

# %% [markdown]
# <a href="#top">Return to the top</a>
#
# <a id="ifilepath"></a>
# ######Imports the files
#
# This points to the directories and files where analysis files are located. If the directories are not avaliable, they can be downloaded without processing. This notebook focuses on samples from the total data set (), a single sample per indiviudal, and a single sample per person int he healthy subset. The
# The data will be downloaded using cURL if the files cannot be found.
#
# The data is assumed to be saved in a directory called <font color="darkblue">AGPanalysis</font> in the parent directory of the current directory. (It is assumed the filepath is located in the current, notebook directory). To change the location of these files, the <code>base_dir</code> can be changed to an alternative lcoation.
#
# We can begin by setting up directories to save the files which will be downloaded and handled here. The default setting is to perform the analysis in a new directory, <font color="darkblue">AGPanalysis</font> in the parent directory of the current directory (assumed to be the notebook directory).
#
# To change where data is saved, the <code>base_dir</code> should be set. By default, it's set to the
#
# The downloaded directory will contain all the necessary files, and filenames.

# %%
# Sets up the base directory
base_dir = pjoin(abspath('..'), 'agp_analysis')
check_dir(base_dir)
otu_dir = pjoin(base_dir, "otu_tables")
check_dir(otu_dir)

# Sets the directory where the files should be located.
awt_dir = pjoin(otu_dir, 'all_otus_all_samples')
check_dir(awt_dir)
aws_dir = pjoin(otu_dir, 'all_otus_single_samples')
check_dir(ast_dir)
ass_dir = pjoin(otu_dir, 'all_otus_subset_single_samples')
check_dir(ass_dir)

# Sets the filenames to be imported
awtu_otu_fp = pjoin(awt_dir, 'AGP_100nt_fecal.biom')
awsu_otu_fp = pjoin(ast_dir, 'AGP_100nt_fecal.biom')
assu_otu_fp = pjoin(ass_dir, 'AGP_100nt_fecal.biom')

# We will also download the HMP
hmp_all_dir = pjoin(base_dir, 'hmp')
check_dir(hmp_all_dir)
# Sets the file names to be imported
hmp_otu_fp = pjoin(hmp_all_dir, 'HMP_100nt.biom')
hmp_map_fp = pjoin(hmp_all_dir, 'HMP_100nt.txt')

# %% [markdown]
# Downloads the files if they are not already avaliable.

# %%
# If the directories do not exist, the files are imported using cURL
# if not exists(whol_all_dir) or overwrite:
#     # Downloads the files
#     !curl -OL https://www.dropbox.com/s/lpq0rym8vzap201/AllFecalSubset.tgz
#     # Extracts the data
#     !tar -xzf AG_1_10_fecal_subset.tgz
#     remove(pjoin('.', 'AllFecalSubset.tgz'))
#     # Moves the directory to the correct location
#     move(pjoin('.', 'AllFecalSubset/'), base_dir)
    

# Loads the unfiltered files into python
awt_otu = load_table(awtu_otu_fp)
aws_otu = load_table(astu_otu_fp)
ass_otu = load_table(assu_otu_fp)

# Loads the HMP data into ipython
if not exists(hmp_otu_fp) or overwrite:
    # Downloads the data
    # !curl -OL https://github.com/biocore/American-Gut/raw/master/data/HMP/HMPv35_100nt.biom.gz
    # !curl -OL https://github.com/biocore/American-Gut/raw/master/data/HMP/HMPv35_100nt.txt
    # Unzip the file
    # !gunzip HMPv35_100nt.biom.gz
    # Moves the data to the correct location
    move(pjoin(abspath('.'), 'HMPv35_100nt.biom'), hmp_otu_fp)
    move(pjoin(abspath('.'), 'HMPv35_100nt.txt'), hmp_map_fp)

hmp_otu = load_table(hmp_otu_fp)

# %% [markdown]
# <a href="#top">Return to the top</a>
#
# <a id="rare"></a>
#
# We can start by writing a function which will repeatedly calculate rarefaction over the

# %%
def calculate_rare_samples(table, depth, samples, num_iter=5):
    """Determines the number of otus from a set of rarefactions"""
    depth_watch = zeros((num_iter, len(samples)))

    # Preforms the rarefactions
    for id1 in xrange(num_iter):
        # Gets the rarefaction instance
        table2 = table.copy()
        sub1 = table2.subsample(depth)

        # Gets the subsampling
        for id2, samp in enumerate(samples[::-1]):
            # Checks the number of samples can be drawn
            if sub1.shape[1] < samp:
                depth_watch[id1, id2] = nan
                continue
            # Subsamples the table
            sub12 = sub1.copy()
            sub2 = sub12.subsample(samp, by_id=True)
            # Determines the number of OTUs
            depth_watch[id1, len(samples) - (id2 + 1)] = sub2.shape[0]
    return depth_watch

# %%
# Prealocates a holding array
awt_count_mean = zeros((num_rarefactions, num_samples))
awt_count_stdv = zeros((num_rarefactions, num_samples))

ast_count_mean = zeros((num_rarefactions, num_samples))
ast_count_stdv = zeros((num_rarefactions, num_samples))

ass_count_mean = zeros((num_rarefactions, num_samples))
ass_count_stdv = zeros((num_rarefactions, num_samples))

hmp_count_mean = zeros((num_rarefactions, num_samples))
hmp_count_stdv = zeros((num_rarefactions, num_samples))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7d4833f0b63f> in <module>()
#       1 # Prealocates a holding array
# ----> 2 awt_count_mean = zeros((num_rarefactions, num_samples))
#       3 awt_count_stdv = zeros((num_rarefactions, num_samples))
#       4
#       5 ast_count_mean = zeros((num_rarefactions, num_samples))
#
# NameError: name 'zeros' is not defined

# %%
for id1, depth in enumerate(rare_depths):
    print depth
    # Gets the OTU counts for various sample iterations
    awt_depth = calculate_rare_samples(awt_otu, depth, samps_drawn, num_iterations)
    awt_count_mean[id1, :] = awt_depth.mean(0)
    awt_count_stdv[id1, :] = awt_depth.std(0)
    ast_depth = calculate_rare_samples(ast_otu, depth, samps_drawn, num_iterations)
    ast_count_mean[id1, :] = ast_depth.mean(0)
    ast_count_stdv[id1, :] = ast_depth.std(0)
    ass_depth = calculate_rare_samples(ass_otu, depth, samps_drawn, num_iterations)
    ass_count_mean[id1, :] = ass_depth.mean(0)
    ass_count_stdv[id1, :] = ass_depth.std(0)
    hmp_depth = calculate_rare_samples(hmp_otu, depth, samps_drawn, num_iterations)
    hmp_count_mean[id1, :] = hmp_depth.mean(0)
    hmp_count_stdv[id1, :] = hmp_depth.std(0)

# %%
awt_count_mean[awt_count_mean==-1] = nan
awt_count_stdv[awt_count_mean==-1] = nan
ast_count_mean[ast_count_mean==-1] = nan
# ast_count_stdv[ast_count_mean==-1] = nan
ass_count_mean[ass_count_mean==-1] = nan
# ass_count_stdv[ass_count_mean==0] = nan
hmp_count_mean[hmp_count_mean==-1] = nan
hmp_count_stdv[hmp_count_mean==-1] = nan

# %%
awt_count_mean[isnan(awt_count_mean)] = -1
ast_count_mean[isnan(ast_count_mean)] = -1
ass_count_mean[isnan(ass_count_mean)] = -1
hmp_count_mean[isnan(hmp_count_mean)] = -1

# %%
print samps_drawn[:18]
print samps_drawn[[6, 9, 10, 11, 12, 17]]
# Out:
# [  2   4   6   8  10  30  50  70  90 100 150 200 250 300 350 400 450 500]
# [ 50 100 150 200 250 500]

# %%
sub_ast_mean = ast_count_mean[:15,[6, 9, 10, 11, 12, 17]]
sub_ass_mean = ass_count_mean[:15,[6, 9, 10, 11, 12, 17]]
sub_hmp_mean = hmp_count_mean[:15,[6, 9, 10, 11, 12, 17]]

sub_samps = samps_drawn[[6, 9, 10, 11, 12, 17]]
sub_rare = rare_depths[:15]

# %%
print sub_ast_mean[0,:]
print sub_ast_stdv[0,:]
# Out:
# [  748.4  1087.6  1355.2  1567.   1769.4  2437.8]
# [ 19.03260361  19.31424345  26.29372549  45.49725266  51.46105323
#   56.33258382]

# %%
ax = plt.axes()
ax.plot(rare_depths, ass_count_mean.transpose())

# %%
sub_ax = plt.axes()
for idx in xrange(6):
#     sub_ax.plot(sub_rare, sub_ast_mean[:, idx], 'b-')
    sub_ax.plot(sub_rare, sub_ass_mean[:, idx], 'b-')
    sub_ax.plot(sub_rare, sub_hmp_mean[:, idx], 'r-')

# %%
ast_ax = plt.subplot(2, 2, 1)
ass_ax = plt.subplot(2, 2, 2)
hmp_ax = plt.subplot(2, 2, 3)
ast_ax.plot(sub_rare, sub_ast_mean)
ass_ax.plot(sub_rare, sub_ass_mean)
hmp_ax.plot(sub_rare, sub_hmp_mean)

# %%
ax_awt = plt.subplot(2,2,1)
ax_ast = plt.subplot(2,2,2)
ax_ass = plt.subplot(2,2,3)
ax_hmp = plt.subplot(2,2,4)
# ax_awt.imshow(awt_count_mean, cmap='gray')
ax_awt.contour(samps_drawn, rare_depths, awt_count_mean.transpose(), levels=arange(0, 15000, 1000), cmap='nipy_spectral')
ax_ast.contour(samps_drawn, rare_depths, ast_count_mean.transpose(), levels=arange(0, 15000, 1000), cmap='nipy_spectral')
ax_ass.contour(samps_drawn, rare_depths, ass_count_mean.transpose(), levels=arange(0, 15000, 1000), cmap='nipy_spectral')
ax_hmp.contour(samps_drawn, rare_depths, hmp_count_mean.transpose(), levels=arange(0, 15000, 1000), cmap='nipy_spectral')
ax_awt.set_xticklabels('')
ax_awt.set_yticklabels(map(int, ax_awt.get_yticks()/1000), size=11)
ax_ass.set_yticklabels(map(int, ax_ast.get_yticks()/1000), size=11)
ax_ass.set_xticklabels(map(int, ax_ast.get_xticks()), size=11)
ax_ast.set_xticklabels('')
ax_ast.set_yticklabels('')
ax_hmp.set_yticklabels('')
ax_hmp.set_xticklabels(map(int, ax_hmp.get_xticks()), size=11)
xlab = ax_ass.set_xlabel('Number of Samples', size=15)
xlab.set_position((1.1, xlab.get_position()[1]))
ylab = ax_ass.set_ylabel('Observed OTUs (x1000)', size=15)
ylab.set_position((ylab.get_position()[0], 1.1))
ax_awt.set_title('AGP', size=15)
ax_ast.set_title('AGP; single sample', size=15)
ax_ass.set_title('AGP; healthy subset', size=15)
ax_hmp.set_title('HMP', size=15)
fig = plt.gcf()

# %%
ax = plt.axes()
ax.contour(samps_drawn, rare_depths, (ass_count_mean - hmp_count_mean).transpose(), 
           levels=arange(0, 10000, 250), cmap='gist_heat_r')
ax.set_xticklabels(map(int, ax.get_xticks()), size=12)
ax.set_yticklabels(map(int, ax.get_yticks()/1000), size=12)
ax.set_xlabel('Number of Samples', size=15)
ax.set_ylabel('Number of OTUs (x 1000)', size=15)
fig = plt.gcf()

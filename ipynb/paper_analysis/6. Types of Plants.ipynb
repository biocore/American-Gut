# %%
# %matplotlib inline

# %% [markdown]
# <a id="top"></a>
#
# #Types of Plants
# <p>...</p>
#
# ####Notebook Requirements
# <ul><li>cURL
# </li><li>Python 2.7
# </li><li>Numpy $\geq$ 1.7
# </li><li>Biom format 2.0.1
# </li><li>Pandas 0.14.1
# </li><li>StatsModel 0.5.0
# </li><li>Scikit bio 0.1.4
# </li><li>Qiime 1.8.0-dev
# </li><li>Custom code libraries, <a href="">pandas_fun.py</a> and <a href="">power.py</a>.
# </li></ul>
#
# ####Table of contents
# <ul><li><a href="#parameters">Sets analysis parameters</a>
# </li><li><a href="#ifilepath">Imports necessary files</a>
# </li><li><a href="#gender">Gender</a>
# <ul><li><a href="#g_alpha">Alpha Diversity</a>
# </li><li><a href="#g_beta">Beta Diversity</a>
# </li><li><a href="#g_gs">Group Signifigance</a>
# </li></ul>
# </li><li><a href="#age_decade">Age by Decade</a>
# </li></ul>
#
#
# We start by importing necessary functions, and determining if files should be overwritten.

# %%
# File handling
from os import remove, rename
from os.path import abspath, isfile, exists, join as pjoin
# Random sampling
from random import sample
# Numerical operations
from numpy import nan, isnan, mean, std, hstack
# Statitics
from scipy.stats import kruskal
from statsmodels.stats.power import FTestAnovaPower
# Plotting
from matplotlib import rcParams
import matplotlib.pylab as plt
# Pandas data frame
from pandas import read_csv, Series, DataFrame
# Distance matrix handling
from skbio import DistanceMatrix
# Biom handling
from biom import load_table
# Specialzied function
from jwd_code.pandas_fun import (check_dir, 
                                 pad_index,
                                 pretty_pandas_boxplot,
                                 post_hoc_pandas,
                                 compare_beta_diversity,
                                 split_taxa,
                                 make_duel_heatmaps)

from power.power_analysis import bootstrap_power_curve, get_paired_subsamples

# Writes a file to save the json string tables
def write_biom(table, fp):
    """Writes a biom table as a json string"""
    file_ = open(fp, 'w')
    file_.write(table.to_json(''))
    file_.close()
# Out:
# /Users/jwdebelius/.virtualenvs/qiime_dev/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# We will also set up some plotting parameters so the generated figures use Helvetica or Arial as their default font.

# %%
# Sets up plotting parameters so that the default setting is use to Helvetica
# in plots
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica', 'Arial']
rcParams['text.usetex'] = True

# %% [markdown]
# <a href=#top>Return to the top</a>
#
# <a id="parameters"></a>
# ###### Sets analysis parameters
#
# We can also set some necessary parameters for handling files and this analysis.

# %%
overwrite = False

# Sets parameters for reading tables into pandas
txt_delim = '\t'
map_index = '#SampleID'
map_nas = ['NA', 'no_data', 'unknown']
write_na = ''

# Sets paramaters for alpha diversity
a_div_metric = 'PD_whole_tree_mean'
a_ylabel = 'PD Whole Tree Diversity'

# Sets the parameters to show for the beta diversity summary
show_beta = ['Group 1', 'Group 2', 
             'Parametric p-value (Bonferroni-corrected)', 
             'Nonparametric p-value (Bonferroni-corrected)']

# Sets up the categories and their ordering
plants = 'TYPES_OF_PLANTS'
p_order = ['Less than 5', '6 to 10', '11 to 20', '21 to 30', 'More than 30']

# %% [markdown]
# <a href="#top">Return to the top</a>
#
# <a id="ifilepath"></a>
# ######Imports the files
#
# This points to the directories and files where analysis files are located. If the directories are not avaliable, they can be downloaded without processing. This notebook focuses on samples from the <a href="https://www.dropbox.com/s/c54ggzikun6rjcm/AG_1_10_fecal_subset.tgz">American Gut rounds 1-10 healthy subset</a> and then <a href="https://www.dropbox.com/s/5ufd2v92i633q1i/AG_1_10_filtered_fecal_subset.tgz">filtered American Gut rounds 1-10 healthy subset</a>. The data will be downloaded using cURL if the files cannot be found.
#
# The data is assumed to be saved in a directory called <font color="darkblue">AGPanalysis</font> in the parent directory of the current directory. (It is assumed the filepath is located in the current, notebook directory). To change the location of these files, the <code>base_dir</code> can be changed to an alternative lcoation.
#
# We can begin by setting up directories to save the files which will be downloaded and handled here. The default setting is to perform the analysis in a new directory, <code>AGPanalysis</code> in the parent directory of the current directory (assumed to be the notebook directory).
#
# To change where data is saved, the <code>base_dir</code> should be set.
#
# The downloaded directory will contain all the necessary files, and filenames.
#
# This notebook will use files with the ending description <font color="firebrick">"_single"</font>, denoting they have been filtered down to have only a single sample per indiviudal.

# %%
# Sets up the base directory
base_dir = pjoin(abspath('..'), 'AGPanalysis')
check_dir(base_dir)
otu_dir = pjoin(base_dir, 'OTUtables')

# Sets the directory where the files should be located
aws_dir = pjoin(otu_dir, 'all_otus_single_samples')
ass_dir = pjoin(otu_dir, 'all_otus_subset_single_samples')
fws_dir = pjoin(otu_dir, 'filtered_otus_single_samples')

# Sets the subset filepath for all samples
awsr_otu_fp = pjoin(aws_dir, 'AGP_100nt_fecal_even10k.biom')
awsr_map_fp = pjoin(aws_dir, 'AGP_100nt_fecal_even10k.txt')
awsr_ubd_fp = pjoin(aws_dir, 'unweighted_unifrac_AGP_100nt_fecal_even10k.txt')
awsr_wbd_fp = pjoin(aws_dir, 'weighted_unifrac_AGP_100nt_fecal_even10k.txt')

assr_otu_fp = pjoin(ass_dir, 'AGP_100nt_fecal_even10k.biom')
assr_map_fp = pjoin(ass_dir, 'AGP_100nt_fecal_even10k.txt')
assr_ubd_fp = pjoin(ass_dir, 'unweighted_unifrac_AGP_100nt_fecal_even10k.txt')
assr_wbd_fp = pjoin(ass_dir, 'weighted_unifrac_AGP_100nt_fecal_even10k.txt')

# Sets the subset filepath for the filtered samples
fwsr_otu_fp = pjoin(fws_dir, 'AGP_100nt_fecal_even10k.biom')
fwsr_map_fp = pjoin(fws_dir, 'AGP_100nt_fecal_even10k.txt')
fwsr_ubd_fp = pjoin(fws_dir, 'unweighted_unifrac_AGP_100nt_fecal_even10k.txt')
fwsr_wbd_fp = pjoin(fws_dir, 'weighted_unifrac_AGP_100nt_fecal_even10k.txt')

# Performs pairwise beta diversity comparisons
beta_dir = pjoin(base_dir, 'BetaDiversity')
check_dir(beta_dir)
aws_ubd_dir = pjoin(beta_dir, 'all_otus_single_samples_unweighted_unifrac')
check_dir(aws_ubd_dir)
aws_wbd_dir = pjoin(beta_dir, 'all_otus_single_samples_weighted_unifrac')
check_dir(aws_wbd_dir)
prd_ubd_dir = pjoin(beta_dir, 'all_otus_paired_single_samples_unweighted_unifrac')
check_dir(prd_ubd_dir)
prd_wbd_dir = pjoin(beta_dir, 'all_otus_paired_single_samples_weighted_unifrac')
check_dir(prd_wbd_dir)

gs_dir = pjoin(base_dir, 'GroupSignifigance')
check_dir(gs_dir)
# fws_ubd_dir = pjoin(beta_dir, 'filtered_otus_single_samples_unweighted_unifrac')
# check_dir(fws_ubd_dir)
# fws_wbd_dir = pjoin(beta_dir, 'filtered_otus_single_samples_weighted_unifrac')
# check_dir(fws_wbd_dir)

# %% [markdown]
# Downloads the files if they are not already avaliable.

# %%
# # If the directories do not exist, the files are imported using cURL
# if not exists(whol_sub_dir) or overwrite:
#     # Downloads the files
#     !curl -OL https://www.dropbox.com/s/lpq0rym8vzap201/AllFecalSubset.tgz
#     # Extracts the data
#     !tar -xzf AG_1_10_fecal_subset.tgz
#     remove(pjoin('.', 'AllFecalSubset.tgz'))
#     # Moves the directory to the correct location
#     move(pjoin('.', 'AllFecalSubset/'), base_dir)
    
# # If the directories do not exist, the files are imported using cURL
# if not exists(filt_sub_dir) or overwrite:
#     # Downloads the files
#     !curl -OL https://www.dropbox.com/s/r1787sym9lvd7gc/FilteredFecalSubset.tgz
#     # Extracts the data
#     !tar -xzf AG_1_10_fecal_subset.tgz
#     remove(pjoin('.', 'FilteredFecalSubset.tgz'))
#     # Moves the directory to the correct location
#     move(pjoin('.', 'FilteredFecalSubset'), base_dir)
    
# Loads the unfiltered files into python
aws_otu = load_table(awsr_otu_fp)
aws_map = pad_index(read_csv(awsr_map_fp,
                            sep=txt_delim, 
                            na_values=map_nas),
                   index_col=map_index)
aws_ubd = DistanceMatrix.from_file(awsr_ubd_fp)
aws_wbd = DistanceMatrix.from_file(awsr_wbd_fp)

ass_otu = load_table(assr_otu_fp)
ass_map = pad_index(read_csv(assr_map_fp,
                            sep=txt_delim, 
                            na_values=map_nas),
                   index_col=map_index)
ass_ubd = DistanceMatrix.from_file(assr_ubd_fp)
ass_wbd = DistanceMatrix.from_file(assr_wbd_fp)

# Loads the filtered files into python
fws_otu = load_table(fwsr_otu_fp)
fws_map = pad_index(read_csv(fwsr_map_fp,
                            sep=txt_delim, 
                            na_values=map_nas),
                   index_col=map_index)
fws_ubd = DistanceMatrix.from_file(fwsr_ubd_fp)
fws_wbd = DistanceMatrix.from_file(fwsr_wbd_fp)

# %% [markdown]
# <a href="#top">Return to the top</a>
#
# <a id="gender"></a>
# ###Gender
#
# Need More text here... blah blah, happy gender.
#
# <a id="g_alpha"></a>
# #####Alpha Diversity
# We can start by looking at the difference in alpha diversity between the sets of healthy samples.

# %%
ass_plants_a_ax, ass_plants_a_feats = \
    pretty_pandas_boxplot(ass_map, plants, p_order, a_div_metric,
                          boxplot_props= {'ylabel': a_ylabel,
                                           'title': "Plants: Alpha Diversity",
                                           'ylims': [10, 55],
                                           'hide_xticks': True})
ass_plants_a_fig = ass_plants_a_ax.figure

# Preforms a post-hoc test
ass_plants_a_post = post_hoc_pandas(ass_map.groupby(plants),
                                 order=p_order,
                                 cat=a_div_metric)
ass_plants_a_post
# Out:
#               Counts       Mean     Median      Stdv  Less than 5  6 to 10  \
# Less than 5       43  30.583678  29.607452  5.830568          NaN      NaN
# 6 to 10          172  33.621501  33.675125  5.224569     0.005767      NaN
# 11 to 20         290  33.956701  34.151099  6.193325     0.003814        1
# 21 to 30         191  33.862025  33.973749  5.792866     0.003612        1
# More than 30     148  34.574737  34.675385  5.629657     0.000382        1
#
#               11 to 20  21 to 30
# Less than 5        NaN       NaN
# 6 to 10            NaN       NaN
# 11 to 20           NaN       NaN
# 21 to 30             1       NaN
# More than 30         1         1

# %% [markdown]
# We can also try drawing a set of comparable samples, controlling for collection season, antibiotic use, IBD, sleep duration, exercise, and alcohol use and age. However, I will not exclude absed on these criteria.

# %%
# Maps sleep duration so that less than 6 hours are combined
aws_map.loc[aws_map.SLEEP_DURATION == 'Less than 5 hours', 'SLEEP_DURATION'] = 'Less than 6 hours'
aws_map.loc[aws_map.SLEEP_DURATION == '5-6 hours', 'SLEEP_DURATION'] = 'Less than 6 hours'
# Gets the paired samples
control_categories = ['IBD', 'BMI_CAT', 'DIABETES', 'ANTIBIOTIC_SELECT', 'AGE_CAT']
plants_paired_ids = get_paired_subsamples(aws_map, plants, control_categories, order=p_order)
# Checks the number of ids
print 'There are %i paired samples.' % plants_paired_ids[0].shape[0]

# Rearranges the paired samples back into a list
plants_ids = plants_paired_ids[0]
for ids in plants_paired_ids[1:]:
    plants_ids = hstack((plants_ids, ids))

# Filters the table down to the samples
plants_paired_table = aws_map.loc[plants_ids]

# Plots the alpha diversity data
paired_plants_a_ax, paired_plants_a_feats = \
    pretty_pandas_boxplot(plants_paired_table, 
                          plants, 
                          p_order, 
                          a_div_metric,
                          boxplot_props= {'ylabel': a_ylabel,
                                           'title': "Types of Plants: Alpha Diversity",
                                           'ylims': [15, 55],
                                           'hide_xticks': True,
                                           'show_n': False})
# Preforms a post-hoc test
paired_plants_a_post = post_hoc_pandas(plants_paired_table.groupby(plants),
                                    order=p_order,
                                    cat=a_div_metric)
paired_plants_a_post
# Out:
# There are 56 paired samples.
#               Counts       Mean     Median      Stdv  Less than 5   6 to 10  \
# Less than 5       56  30.716580  30.014421  5.921475          NaN       NaN
# 6 to 10           56  32.243118  32.786205  5.858477     1.000000       NaN
# 11 to 20          56  33.279504  34.363956  6.116073     0.136121  1.000000
# 21 to 30          56  33.397923  32.964769  6.192823     0.119406  1.000000
# More than 30      56  34.972951  35.512946  6.326032     0.002353  0.167709
#
#               11 to 20  21 to 30
# Less than 5        NaN       NaN
# 6 to 10            NaN       NaN
# 11 to 20           NaN       NaN
# 21 to 30             1       NaN
# More than 30         1         1

# %% [markdown]
# There is no signifigant difference in alpha diversity between men and women for the over all data, or the paired samples.
#
# <a id="g_beta"></a>
# #####Beta Diversity
#
# I'd also like to check beta diversity, using a Permanova. If this shows a signfigant difference, I can try to look for the difference between the male and female samples, starting with unweighted UniFrac. I'll start by performing pairwise t-tests for distance for all the betadiversity matrices.
#
# I'm going to start by filtering the beta diversity tables and filtered mapping files for the sex-paired samples, and then calculate the paired beta diversity for the

# %%
# Filters the beta diversity
paired_plants_ubd = aws_ubd.filter(plants_ids)
paired_plants_wbd = aws_wbd.filter(plants_ids)

# Saves the temporary files
temp_ubd_fp = pjoin(base_dir, 'temp_unweighted_unifrac.txt')
temp_wbd_fp = pjoin(base_dir, 'temp_weighted_unifrac.txt')
temp_map_fp = pjoin(base_dir, 'temp_AGP_mapping.txt')
if not exists(temp_ubd_fp):
    paired_plants_ubd.to_file(temp_ubd_fp)
if not exists(temp_wbd_fp):
    paired_plants_wbd.to_file(temp_wbd_fp)
if not exists(temp_map_fp):
    plants_paired_table.to_csv(temp_map_fp,
                            sep=txt_delim, 
                            na_rep=write_na, 
                            index_label=map_index)

# Calculates the post hoc beta diversity
if not exists(pjoin(prd_ubd_dir, '%s_stats.txt' % plants)) or overwrite:
    # !make_distance_boxplots.py -d $temp_ubd_fp -m $temp_map_fp -f $plants -o $prd_ubd_dir --sort median
if not exists(pjoin(prd_wbd_dir, '%s_stats.txt' % plants)) or overwrite:
    # !make_distance_boxplots.py -d $temp_wbd_fp -m $temp_map_fp -f $plants -o $prd_wbd_dir --sort median

if not exists(pjoin(aws_ubd_dir, '%s_stats.txt' % plants)) or overwrite:
    # !make_distance_boxplots.py -d $assr_ubd_fp -m $assr_map_fp -f $plants -o $aws_ubd_dir --sort median
if not exists(pjoin(aws_wbd_dir, '%s_stats.txt' % plants)) or overwrite:
    # !make_distance_boxplots.py -d $assr_wbd_fp -m $assr_map_fp -f $plants -o $aws_wbd_dir --sort median

# Deletes the temporary files
remove(temp_ubd_fp)
remove(temp_wbd_fp)
remove(temp_map_fp)
    
# Reads in the post-hoc results
ass_plants_ub_post = read_csv(pjoin(aws_ubd_dir, '%s_stats.txt' % plants), 
                           sep=txt_delim, skiprows=[0, 1, 2, 3, 4])
ass_plants_wb_post = read_csv(pjoin(aws_wbd_dir, '%s_stats.txt' % plants), 
                           sep=txt_delim, skiprows=[0, 1, 2, 3, 4])
paired_plants_ub_post = read_csv(pjoin(prd_ubd_dir, '%s_stats.txt' % plants), 
                              sep=txt_delim, skiprows=[0, 1, 2, 3, 4])
paired_plants_wb_post = read_csv(pjoin(prd_wbd_dir, '%s_stats.txt' % plants), 
                              sep=txt_delim, skiprows=[0, 1, 2, 3, 4])

# %% [markdown]
# We can then import the compared beta diveristy results, and plot the distance for each of the tables, starting with unweighted UniFrac for the unfiltered table.

# %%
# Creates a boxplot of the beta diversity
ass_plants_ub_ax, ass_plants_ub_feats = \
    compare_beta_diversity(ass_ubd, ass_map, plants, num_iter=999,
                           show_allbetween=False, show_within=False,
                           violin_props={'ylabel': 'Unweighted UniFrac',
                                          'show_n': False,
                                          'title': 'Gender: Beta Diversity',
                                          'hide_xticks': False,
                                          'ylims': [0.3, 1],
                                          'xfont_angle': 45,
                                          'xfont_align': 'right'})

# Calculates the mean distanc
ass_plants_ub_post.loc[ass_plants_ub_post['Group 1'] == 'All within %s' % plants,
                   ['Group 1', 'Group 2', 'Parametric p-value (Bonferroni-corrected)']]
# Out:
#                         Group 1                       Group 2  \
# 117  All within TYPES_OF_PLANTS         11 to 20 vs. 11 to 20
# 118  All within TYPES_OF_PLANTS      More than 30 vs. 6 to 10
# 119  All within TYPES_OF_PLANTS          6 to 10 vs. 21 to 30
# 120  All within TYPES_OF_PLANTS                  vs. 21 to 30
# 121  All within TYPES_OF_PLANTS                  vs. 11 to 20
# 122  All within TYPES_OF_PLANTS          6 to 10 vs. 11 to 20
# 123  All within TYPES_OF_PLANTS   All between TYPES_OF_PLANTS
# 124  All within TYPES_OF_PLANTS                   vs. 6 to 10
# 125  All within TYPES_OF_PLANTS           6 to 10 vs. 6 to 10
# 126  All within TYPES_OF_PLANTS                          vs.
# 127  All within TYPES_OF_PLANTS      Less than 5 vs. 21 to 30
# 128  All within TYPES_OF_PLANTS      Less than 5 vs. 11 to 20
# 129  All within TYPES_OF_PLANTS       6 to 10 vs. Less than 5
# 130  All within TYPES_OF_PLANTS               vs. Less than 5
# 131  All within TYPES_OF_PLANTS  More than 30 vs. Less than 5
# 132  All within TYPES_OF_PLANTS   Less than 5 vs. Less than 5
#
#      Parametric p-value (Bonferroni-corrected)
# 117                               1.000000e+00
# 118                               1.000000e+00
# 119                               1.301762e-02
# 120                               1.000000e+00
# 121                               1.000000e+00
# 122                               4.678546e-14
# 123                               1.253669e-28
# 124                               1.119145e-01
# 125                               2.173458e-20
# 126                               1.000000e+00
# 127                              5.688548e-239
# 128                               0.000000e+00
# 129                              1.097212e-261
# 130                               9.487935e-26
# 131                              2.061073e-218
# 132                               8.649198e-58

# %%
# Creates a boxplot of the beta diversity
ass_plants_wb_ax, ass_plants_wb_feats = \
    compare_beta_diversity(ass_wbd, ass_map, plants, num_iter=999,
                           show_allbetween=False, show_within=False,
                           violin_props={'ylabel': 'Weighted UniFrac',
                                          'show_n': False,
                                          'title': 'Types of Vegetables: Beta Diversity',
                                          'xfont_angle': 45,
                                          'xfont_align': 'right'})

# Calculates the mean distanc
ass_plants_wb_post.loc[ass_plants_wb_post['Group 1'] == 'All within %s' % plants,
                   ['Group 1', 'Group 2', 'Parametric p-value (Bonferroni-corrected)']]
# Out:
#                         Group 1                       Group 2  \
# 162  All within TYPES_OF_PLANTS          6 to 10 vs. 21 to 30
# 163  All within TYPES_OF_PLANTS      More than 30 vs. 6 to 10
# 164  All within TYPES_OF_PLANTS         11 to 20 vs. 11 to 20
# 165  All within TYPES_OF_PLANTS                   vs. 6 to 10
# 166  All within TYPES_OF_PLANTS   All between TYPES_OF_PLANTS
# 167  All within TYPES_OF_PLANTS          6 to 10 vs. 11 to 20
# 168  All within TYPES_OF_PLANTS           6 to 10 vs. 6 to 10
# 169  All within TYPES_OF_PLANTS      Less than 5 vs. 21 to 30
# 170  All within TYPES_OF_PLANTS      Less than 5 vs. 11 to 20
# 171  All within TYPES_OF_PLANTS       6 to 10 vs. Less than 5
# 172  All within TYPES_OF_PLANTS  More than 30 vs. Less than 5
# 173  All within TYPES_OF_PLANTS               vs. Less than 5
# 174  All within TYPES_OF_PLANTS   Less than 5 vs. Less than 5
#
#      Parametric p-value (Bonferroni-corrected)
# 162                               1.307144e-02
# 163                               1.000000e+00
# 164                               1.000000e+00
# 165                               1.000000e+00
# 166                               2.258189e-12
# 167                               6.541122e-08
# 168                               6.703276e-19
# 169                              4.709792e-104
# 170                              3.114820e-193
# 171                              5.205384e-148
# 172                              3.064846e-119
# 173                               6.144824e-14
# 174                               2.800626e-28

# %%
# Creates a boxplot of the beta diversity
prd_plants_ub_ax, prd_plants_ub_feats = \
    compare_beta_diversity(paired_plants_ubd, plants_paired_table, plants, num_iter=999,
                           show_allbetween=False, show_within=False,
                           violin_props={'ylabel': 'Unweighted UniFrac',
                                          'show_n': False,
                                          'title': 'Gender: Beta Diversity',
                                          'hide_xticks': True,
                                          'ylims': [0.3, 1],
                                          'xfont_angle': 45,
                                          'xfont_align': 'right'})

# Calculates the mean distanc
paired_plants_ub_post.loc[paired_plants_ub_post['Group 1'] == 'All within %s' % plants,
                       ['Group 1', 'Group 2', 'Parametric p-value (Bonferroni-corrected)']]
# Out:
#                         Group 1                       Group 2  \
# 198  All within TYPES_OF_PLANTS     More than 30 vs. 11 to 20
# 199  All within TYPES_OF_PLANTS           6 to 10 vs. 6 to 10
# 200  All within TYPES_OF_PLANTS   All between TYPES_OF_PLANTS
# 201  All within TYPES_OF_PLANTS      More than 30 vs. 6 to 10
# 202  All within TYPES_OF_PLANTS      Less than 5 vs. 11 to 20
# 203  All within TYPES_OF_PLANTS       6 to 10 vs. Less than 5
# 204  All within TYPES_OF_PLANTS      Less than 5 vs. 21 to 30
# 205  All within TYPES_OF_PLANTS               vs. Less than 5
# 206  All within TYPES_OF_PLANTS   Less than 5 vs. Less than 5
# 207  All within TYPES_OF_PLANTS  More than 30 vs. Less than 5
#
#      Parametric p-value (Bonferroni-corrected)
# 198                               1.000000e+00
# 199                               1.000000e+00
# 200                               4.313559e-12
# 201                               5.407626e-06
# 202                               3.896446e-72
# 203                               9.063901e-61
# 204                               2.420651e-64
# 205                               6.745412e-05
# 206                               5.016741e-18
# 207                               1.254030e-89

# %%
prd_plants_wb_ax, prd_plants_wb_feats = \
    compare_beta_diversity(paired_plants_wbd, plants_paired_table, plants, num_iter=999,
                           show_allbetween=False, show_within=False,
                           violin_props={'ylabel': 'Weighted UniFrac',
                                          'show_n': False,
                                          'title': 'Gender: Beta Diversity',
                                          'xfont_angle': 45,
                                          'xfont_align': 'right'})

# Calculates the mean distanc
paired_plants_wb_post.loc[paired_plants_wb_post['Group 1'] == 'All within %s' % plants,
                       ['Group 1', 'Group 2', 'Parametric p-value (Bonferroni-corrected)']]
# Out:
#                         Group 1                        Group 2  \
# 117  All within TYPES_OF_PLANTS           6 to 10 vs. 21 to 30
# 118  All within TYPES_OF_PLANTS    Less than 5 vs. Less than 5
# 119  All within TYPES_OF_PLANTS                    vs. 6 to 10
# 120  All within TYPES_OF_PLANTS               vs. More than 30
# 121  All within TYPES_OF_PLANTS                   vs. 11 to 20
# 122  All within TYPES_OF_PLANTS            6 to 10 vs. 6 to 10
# 123  All within TYPES_OF_PLANTS      More than 30 vs. 21 to 30
# 124  All within TYPES_OF_PLANTS    All between TYPES_OF_PLANTS
# 125  All within TYPES_OF_PLANTS       Less than 5 vs. 11 to 20
# 126  All within TYPES_OF_PLANTS        6 to 10 vs. Less than 5
# 127  All within TYPES_OF_PLANTS      More than 30 vs. 11 to 20
# 128  All within TYPES_OF_PLANTS       More than 30 vs. 6 to 10
# 129  All within TYPES_OF_PLANTS       Less than 5 vs. 21 to 30
# 130  All within TYPES_OF_PLANTS  More than 30 vs. More than 30
# 131  All within TYPES_OF_PLANTS   More than 30 vs. Less than 5
# 132  All within TYPES_OF_PLANTS                vs. Less than 5
#
#      Parametric p-value (Bonferroni-corrected)
# 117                               1.000000e+00
# 118                               1.000000e+00
# 119                               1.000000e+00
# 120                               1.000000e+00
# 121                               1.000000e+00
# 122                               1.000000e+00
# 123                               1.000000e+00
# 124                               6.007049e-01
# 125                               2.023843e-04
# 126                               2.313779e-03
# 127                               3.859971e-02
# 128                               5.858458e-04
# 129                               3.401187e-06
# 130                               4.164783e-04
# 131                               2.279272e-21
# 132                               2.190268e-04

# %% [markdown]
# There appears to be a signifigant difference in Unweighted UniFrac distance between the genders (corrected p < 1 x 10<sup>-4</sup>, but the difference is not maintained in weighted UniFrac Distance. This suggests differences in taxonomic composition, but not in abundance, or that these taxa are relatively rare. I'd like to use group signifigance to see if we can identify the OTUs which may be driving this distance.
#
# <a href="#top">Return to the top</a>
# <a id="g_gs"></a>
# #####Group Signifigance

# %%
# Gets up the group order
h_order = ['%s_mean' %s for s in p_order]

# Generates the group signifigance results
gs_out = pjoin(gs_dir, 'all_otus_single_subset_%s_kw.txt' % plants)

# Calculates the group signifigance
if not exists(gs_out) or overwrite:
    # !group_significance.py -i $awsr_otu_fp -m $awsr_map_fp -c $plants -o $gs_out

# Loads the group signifigance data
aws_plants_kw_table = read_csv(gs_out, sep=txt_delim)

# Updates the gs table to include taxonomy
if 'OTU' in aws_plants_kw_table.columns:
    aws_plants_kw_table.index = aws_plants_kw_table.OTU

# Converts the taxonomy into tidier blocks
taxa, levels = split_taxa(aws_plants_kw_table.taxonomy.values, 7)
aws_plants_kw_table = aws_plants_kw_table.join(DataFrame(taxa, columns=levels, index=aws_plants_kw_table.index))

# Checks there are signfigant OTUs
if True in aws_plants_kw_table.groupby(aws_plants_kw_table['Bonferroni_P'] < 0.05).groups:
    # Orders the table with something like phylogeny (being able to show distance would be helpful)
    aws_plants_kw_table = aws_plants_kw_table.sort(['phylum', 'p_class', 'p_order',
                                              'family', 'genus', 'species'])
    # Adds a labeling column
    aws_plants_kw_table['label'] = aws_plants_kw_table['genus'] + ' (' + \
        aws_plants_kw_table['OTU'].apply(lambda x: str(x)) + ')'
    # Plots the heatmap
    aws_plants_hm_feat, aws_plants_fig = \
        make_duel_heatmaps(aws_plants_kw_table,
                           p_value='Bonferroni_P',
                           order=h_order,
                           label='label',
                           clims2=[-0.75, 0.75],
                           yfont_size=9,
                           xfont_angle=45,
                           xfont_align='right')
else:
    print 'There are no signifignatly different OTUs.'

# %%
# Generates the group signifigance results
gs_out = pjoin(gs_dir, 'all_otus_single_subset_%s_gt.txt' % plants)

# Calculates the group signifigance
if not exists(gs_out) or overwrite:
    # !group_significance.py -i $awsr_otu_fp -m $awsr_map_fp -c $plants -o $gs_out -s g_test

# Loads the group signifigance data
aws_plants_gt_table = read_csv(gs_out, sep=txt_delim)

# Updates the gs table to include taxonomy
if 'OTU' in aws_plants_gt_table.columns:
    aws_plants_gt_table.index = aws_plants_gt_table.OTU

# Converts the taxonomy into tidier blocks
taxa, levels = split_taxa(aws_plants_gt_table.taxonomy.values, 7)
aws_plants_gt_table = aws_plants_gt_table.join(DataFrame(taxa, columns=levels, index=aws_plants_gt_table.index))

# Checks there are signfigant OTUs
if True in aws_plants_gt_table.groupby(aws_plants_gt_table['Bonferroni_P'] < 0.05).groups:
    # Orders the table with something like phylogeny (being able to show distance would be helpful)
    aws_plants_gt_table = aws_plants_gt_table.sort(['phylum', 'p_class', 'p_order',
                                              'family', 'genus', 'species'])
    # Adds a labeling column
    aws_plants_gt_table['label'] = aws_plants_gt_table['genus'] + ' (' + \
        aws_plants_gt_table['OTU'].apply(lambda x: str(x)) + ')'
    # Plots the heatmap
    aws_plants_hm_feat, aws_plants_fig = \
        make_duel_heatmaps(aws_plants_gt_table,
                           p_value='Bonferroni_P',
                           order=h_order,
                           label='label',
                           clims2=[-1, 1],
                           yfont_size=9,
                           xfont_angle=45,
                           xfont_align='right')
else:
    print 'There are no signifignatly different OTUs.'

# %%
# Filters the beta diversity
paired_plants_ubd = aws_ubd.filter(plants_ids)
paired_plants_wbd = aws_wbd.filter(plants_ids)
paired_plants_otu = aws_otu.filter(plants_ids)

# Saves the temporary files
temp_ubd_fp = pjoin(base_dir, 'temp_unweighted_unifrac.txt')
temp_wbd_fp = pjoin(base_dir, 'temp_weighted_unifrac.txt')
temp_map_fp = pjoin(base_dir, 'temp_AGP_mapping.txt')
temp_otu_fp = pjoin(base_dir, 'temp_AGP_otus.biom')
if not exists(temp_ubd_fp):
    paired_plants_ubd.to_file(temp_ubd_fp)
if not exists(temp_wbd_fp):
    paired_plants_wbd.to_file(temp_wbd_fp)
if not exists(temp_map_fp):
    plants_paired_table.to_csv(temp_map_fp,
                            sep=txt_delim, 
                            na_rep=write_na, 
                            index_label=map_index)
if not exists(temp_otu_fp):
    write_biom(paired_plants_otu, temp_otu_fp)
    
# Generates the group signifigance results
gs_out = pjoin(gs_dir, 'all_otus_paired_single_%s_kw.txt' % plants)

# Calculates the group signifigance
# if not exists(gs_out) or overwrite:
# !group_significance.py -i $temp_otu_fp -m $temp_map_fp -c $plants -o $gs_out

# Loads the group signifigance data
paired_plants_kw_table = read_csv(gs_out, sep=txt_delim)

# Updates the gs table to include taxonomy
if 'OTU' in paired_plants_kw_table.columns:
    paired_plants_kw_table.index = paired_plants_kw_table.OTU

# Converts the taxonomy into tidier blocks
taxa, levels = split_taxa(paired_plants_kw_table.taxonomy.values, 7)
paired_plants_kw_table = paired_plants_kw_table.join(DataFrame(taxa, columns=levels, index=paired_plants_kw_table.index))

# Checks there are signfigant OTUs
if True in paired_plants_kw_table.groupby(paired_plants_kw_table['Bonferroni_P'] < 0.05).groups:
    # Orders the table with something like phylogeny (being able to show distance would be helpful)
    paired_plants_kw_table = paired_plants_kw_table.sort(['phylum', 'p_class', 'p_order',
                                              'family', 'genus', 'species'])
    # Adds a labeling column
    paired_plants_kw_table['label'] = paired_plants_kw_table['genus'] + ' (' + \
        paired_plants_kw_table['OTU'].apply(lambda x: str(x)) + ')'
    # Plots the heatmap
    paired_plants_hm_feat, paired_plants_fig = \
        make_duel_heatmaps(paired_plants_kw_table,
                           p_value='Bonferroni_P',
                           order=h_order,
                           label='label',
                           clims2=[-0.75, 0.75],
                           yfont_size=9)
    paired_plants_fig.set_size_inches((6, 3))
else:
    print 'There are no signifignatly different OTUs.'
# Out:
# There are no signifignatly different OTUs.

# %%
# Generates the group signifigance results
gs_out = pjoin(gs_dir, 'all_otus_paired_single_%s_gt.txt' % plants)

# Calculates the group signifigance
if not exists(gs_out) or overwrite:
    # !group_significance.py -i $temp_otu_fp -m $temp_map_fp -c $plants -o $gs_out -s g_test

# Loads the group signifigance data
paired_plants_gt_table = read_csv(gs_out, sep=txt_delim)

# Updates the gs table to include taxonomy
if 'OTU' in paired_plants_gt_table.columns:
    paired_plants_gt_table.index = paired_plants_gt_table.OTU
    
# Converts the taxonomy into tidier blocks
taxa, levels = split_taxa(paired_plants_gt_table.taxonomy.values, 7)
paired_plants_gt_table = paired_plants_gt_table.join(DataFrame(taxa, columns=levels, index=paired_plants_gt_table.index))
# Fixes a problematic taxonomy string
paired_plants_gt_table.loc[paired_plants_gt_table.genus == 'WAL_1855D', 'genus'] = 'WAL 1855D'
# Checks there are signfigant OTUs
if True in paired_plants_gt_table.groupby(paired_plants_gt_table['Bonferroni_P'] < 0.05).groups:
    # Orders the table with something like phylogeny (being able to show distance would be helpful)
    paired_plants_gt_table = paired_plants_gt_table.sort(['phylum', 'p_class', 'p_order',
                                              'family', 'genus', 'species'])
    # Adds a labeling column
    paired_plants_gt_table['label'] = paired_plants_gt_table['genus'] + ' (' + \
        paired_plants_gt_table['OTU'].apply(lambda x: str(x)) + ')'
    # Plots the heatmap
    paired_plants_hm_feat, paired_plants_fig = \
        make_duel_heatmaps(paired_plants_gt_table,
                           p_value='Bonferroni_P',
                           order=h_order,
                           label='label',
                           clims2=[-2, 2],
                           yfont_size=8,
                           xfont_angle=45,
                           xfont_align='right')
    paired_plants_fig.set_size_inches((12, 8))
else:
    print 'There are no signifignatly different OTUs.'

# %%
   
# Deletes the temporary files
if exists(temp_ubd_fp):
    remove(temp_ubd_fp)
if exists(temp_wbd_fp):
    remove(temp_wbd_fp)
if exists(temp_map_fp):
    remove(temp_map_fp)
if exists(temp_otu_fp):
    remove(temp_otu_fp)
